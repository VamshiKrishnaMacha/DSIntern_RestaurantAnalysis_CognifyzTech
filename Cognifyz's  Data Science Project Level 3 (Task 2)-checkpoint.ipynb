# %% [markdown]
# ## Task: Customer Preference Analysis

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('Dataset.csv')

# %%
# Group by cuisine and calculate the total number of votes for each cuisine
popular_cuisines = data.groupby('Cuisines')['Votes'].sum().sort_values(ascending=False).head(10)

# Plot a bar chart to visualize the most popular cuisines based on votes
plt.figure(figsize=(12, 6))
popular_cuisines.plot(kind='bar', color='skyblue')
plt.title('Top 10 Most Popular Cuisines Based on Votes')
plt.xlabel('Cuisine')
plt.ylabel('Total Votes')
plt.show()

# %%
# Group by cuisine and calculate the average rating for each cuisine
average_ratings = data.groupby('Cuisines')['Aggregate rating'].mean().sort_values(ascending=False).head(10)

# Plot a bar chart to visualize the cuisines with the highest average ratings
plt.figure(figsize=(12, 6))
average_ratings.plot(kind='bar', color='salmon')
plt.title('Top 10 Cuisines with Highest Average Ratings')
plt.xlabel('Cuisine')
plt.ylabel('Average Rating')
plt.show()
